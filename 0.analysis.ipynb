# %%
import pandas as pd

# %%
# !pip install openpyxl

# %%
control_df = pd.read_csv('./control_data.csv')

# %%
control_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 240 entries, 0 to 239
# Data columns (total 54 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   TIMEDESC                       240 non-null    object
#  1   YEAR                           240 non-null    int64
#  2   MONTH                          240 non-null    int64
#  3   QAURTER                        240 non-null    int64
#  4   CHANNEL                        240 non-null    object
#  5   CHANNEL_YR                     240 non-null    object
#  6   CHANNEL_MO                     240 non-null    object
#  7   CHANNEL_QR                     240 non-null    object
#  8   CHANNELDESC                    240 non-null    object
#  9   PRODHIERARCHY1                 240 non-null    object
#  10  PRODHIERARCHY2                 240 non-null    int64
#  11  PRODDESC                       240 non-null    object
# ...

# %%
col_info = pd.DataFrame({
    "Column": control_df.columns,
    "Datatype": control_df.dtypes.astype(str)
})

print(col_info.to_string(index=False))
# Out:
#                        Column Datatype
#                      TIMEDESC   object
#                          YEAR    int64
#                         MONTH    int64
#                       QAURTER    int64
#                       CHANNEL   object
#                    CHANNEL_YR   object
#                    CHANNEL_MO   object
#                    CHANNEL_QR   object
#                   CHANNELDESC   object
#                PRODHIERARCHY1   object
#                PRODHIERARCHY2    int64
#                      PRODDESC   object
#                    REGIONDESC   object
#                   REGION_YEAR   object
#                         VALUE  float64
#                        VOLUME  float64
#                            ND  float64
#                            WD  float64
#                  CHANNEL_YEAR   object
#                     PROD_YEAR   object
#               Aided_Awareness  float64
#           Closeness_Top_3_Box  float64
#                       Loyalty  float64
# ...

# %%
col_info.to_csv("col_info.csv", index=False)

# %%
print(control_df.to_string())
# Out:
#           TIMEDESC  YEAR  MONTH  QAURTER                CHANNEL                  CHANNEL_YR                CHANNEL_MO               CHANNEL_QR               CHANNELDESC            PRODHIERARCHY1  PRODHIERARCHY2 PRODDESC REGIONDESC    REGION_YEAR         VALUE       VOLUME         ND         WD                   CHANNEL_YEAR PROD_YEAR  Aided_Awareness  Closeness_Top_3_Box   Loyalty  Top_Of_Mind_Brand_Awareness  Total_unaided_brand_awareness  Chim_Shop_Chai   Panic_pantry_loading  Welfare  Welfare_Additional_boost   BigPack    BuyGet  Extravol  Free_promo  Free_with_others  Freepremium  Near Pack       PMD        RL     Theme       TPR  TARGET_PRICE  TARGET_BASEPRICE  TARGET_DISCOUNT  DARLIE_DISCOUNT  Darlie_CDC_BasePriceRatio  Week5_SI  Week13_SI  Trendline  Consumer_Confidence_Index  Tourist_Arrivals_In_Million  Extravol_Darlie  Free_promo_Darlie  Free_with_others_Darlie  TPR_Darlie
# ...

# %%
control_df.columns
# Out:
# Index(['TIMEDESC', 'YEAR', 'MONTH', 'QAURTER', 'CHANNEL', 'CHANNEL_YR',
#        'CHANNEL_MO', 'CHANNEL_QR', 'CHANNELDESC', 'PRODHIERARCHY1',
#        'PRODHIERARCHY2', 'PRODDESC', 'REGIONDESC', 'REGION_YEAR', 'VALUE',
#        'VOLUME', 'ND', 'WD', 'CHANNEL_YEAR', 'PROD_YEAR', 'Aided_Awareness',
#        'Closeness_Top_3_Box', 'Loyalty', 'Top_Of_Mind_Brand_Awareness',
#        'Total_unaided_brand_awareness', 'Chim_Shop_Chai ',
#        'Panic_pantry_loading', 'Welfare', 'Welfare_Additional_boost',
#        'BigPack', 'BuyGet', 'Extravol', 'Free_promo', 'Free_with_others',
#        'Freepremium', 'Near Pack', 'PMD', 'RL', 'Theme', 'TPR', 'TARGET_PRICE',
#        'TARGET_BASEPRICE', 'TARGET_DISCOUNT', 'DARLIE_DISCOUNT',
#        'Darlie_CDC_BasePriceRatio', 'Week5_SI', 'Week13_SI', 'Trendline',
#        'Consumer_Confidence_Index', 'Tourist_Arrivals_In_Million',
#        'Extravol_Darlie', 'Free_promo_Darlie', 'Free_with_others_Darlie',
#        'TPR_Darlie'],
# ...

# %%
media_df = pd.read_csv('./media_data.csv')

# %%
media_df.columns
# Out:
# Index(['TIMEDESC', 'Year', 'Month', 'Count', 'MODEL_REGION', 'REGIONDESC',
#        'Effect', 'PRODHIERARCHY1', 'Filter_Brand_For_Model', 'Brand',
#        'Vehicle', 'Campaign', 'SubType0', 'SubType1', 'SubType2',
#        'Model Vehicle', 'Type', 'Spend', 'Currency', 'Original Value', 'Fact',
#        'Value', 'Scaled Fact'],
#       dtype='object')

# %%
media_df['Fact'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 32405 entries, 0 to 32404
# Series name: Fact
# Non-Null Count  Dtype
# --------------  -----
# 32405 non-null  object
# dtypes: object(1)
# memory usage: 253.3+ KB

# %%
media_df.shape
# Out:
# (32405, 23)

# %%
media_df.columns
# Out:
# Index(['TIMEDESC', 'Year', 'Month', 'Count', 'MODEL_REGION', 'REGIONDESC',
#        'Effect', 'PRODHIERARCHY1', 'Filter_Brand_For_Model', 'Brand',
#        'Vehicle', 'Campaign', 'SubType0', 'SubType1', 'SubType2',
#        'Model Vehicle', 'Type', 'Spend', 'Currency', 'Original Value', 'Fact',
#        'Value', 'Scaled Fact'],
#       dtype='object')

# %%
media_df[['TIMEDESC','Effect','PRODHIERARCHY1']].drop_duplicates()
# Out:
#             TIMEDESC  Effect            PRODHIERARCHY1
# 0      06-01-17 0:00  Target           OPEN TRADE BLUE
# 2      06-01-17 0:00  Target       OPEN TRADE NON-BLUE
# 7      06-01-17 0:00  Target   SUPER/HYPERMARKET CHAIN
# 15     06-01-17 0:00  Target  LOCAL SUPERMARKET + MTSR
# 20     06-01-17 0:00  Target               CONVENIENCE
# ...              ...     ...                       ...
# 32180  25-12-20 0:00    Halo  LOCAL SUPERMARKET + MTSR
# 32225  25-12-20 0:00    Halo               CONVENIENCE
# 32270  25-12-20 0:00    Halo   SUPER/HYPERMARKET CHAIN
# 32315  25-12-20 0:00    Halo           OPEN TRADE BLUE
# 32360  25-12-20 0:00    Halo       OPEN TRADE NON-BLUE
#
# [2060 rows x 3 columns]

# %%
media_df['TIMEDESC'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 32405 entries, 0 to 32404
# Series name: TIMEDESC
# Non-Null Count  Dtype
# --------------  -----
# 32405 non-null  object
# dtypes: object(1)
# memory usage: 253.3+ KB

# %%
media_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32405 entries, 0 to 32404
# Data columns (total 23 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   TIMEDESC                32405 non-null  object
#  1   Year                    32405 non-null  int64
#  2   Month                   32405 non-null  int64
#  3   Count                   32405 non-null  int64
#  4   MODEL_REGION            32405 non-null  object
#  5   REGIONDESC              32405 non-null  object
#  6   Effect                  32405 non-null  object
#  7   PRODHIERARCHY1          32405 non-null  object
#  8   Filter_Brand_For_Model  32405 non-null  object
#  9   Brand                   32405 non-null  object
#  10  Vehicle                 32405 non-null  object
#  11  Campaign                32405 non-null  object
#  12  SubType0                31355 non-null  object
#  13  SubType1                30385 non-null  object
# ...
